# %%
Hangman = {7:
"""
---------
|       |
|  RIP  |
|       |
|       |
""",
6:
"""
  ------
  |    O
  |   /|\\
  |   / \\
  | 
-----
""",
5:
"""
  ------
  |    O
  |   /|\\
  |   /
  |
-----  
""",
4:
"""
  ------
  |    O
  |   /|\\
  |   
  |
-----  
""" ,
3:
"""
  ------
  |    O
  |   /|
  |   
  |
-----  
""" ,
2:
"""
  ------
  |    O
  |    |
  |   
  |
-----  
""",
1: 
"""
  ------
  |    O
  |   
  |   
  |
-----  
""" ,
0: 
"""
  ------
  |    
  |   
  |   
  |
-----  
"""         }

# %%
for x in range(8):
    print(Hangman[x])
    if x == 7:
        print("Anything right now I don't really care")
# Out:
#   ------
#   |
#   |
#   |
#   |
# -----
#
#
#   ------
#   |    O
#   |
#   |
#   |
# -----
#
#
#   ------
#   |    O
#   |    |
#   |
#   |
# -----
#
#
#   ------
#   |    O
#   |   /|
#   |
#   |
# -----
#
#
#   ------
#   |    O
#   |   /|\
#   |
#   |
# -----
#
#
#   ------
#   |    O
#   |   /|\
#   |   /
#   |
# -----
#
#
#   ------
#   |    O
#   |   /|\
#   |   / \
#   |
# -----
#
#
# ---------
# |       |
# |  RIP  |
# |       |
# |       |
#
# Anything right now I don't really care
